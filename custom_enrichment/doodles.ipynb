# %%
import numpy as np
import pandas as pd
import utils
import glob
import os

# %%
path = "deepfri_predictions"
file_pattern = "*.csv"

# %%
data = utils.load_deepfri_predictions(path, file_pattern)
# Out:
# deepfri_predictions\A0A014P469_BP_predictions.csv
# deepfri_predictions\A0A060W3L5_MF_predictions.csv
# deepfri_predictions\A0A073JMD2_MF_predictions.csv
# deepfri_predictions\A0A076PY04_BP_predictions.csv
# deepfri_predictions\A0A087TBU0_BP_predictions.csv
# deepfri_predictions\A0A0B1STL1_BP_predictions.csv
# deepfri_predictions\A0A0B7H0C7_BP_predictions.csv
# deepfri_predictions\A0A0E3UFT7_CC_predictions.csv
# deepfri_predictions\A0A0E3VUL0_MF_predictions.csv
# deepfri_predictions\A0A0F7M4R0_BP_predictions.csv
# deepfri_predictions\A0A0G1JS24_BP_predictions.csv
# deepfri_predictions\A0A0G1VKI3_CC_predictions.csv
# deepfri_predictions\A0A0G4K477_CC_predictions.csv
# deepfri_predictions\A0A0H3LTJ0_MF_predictions.csv
# deepfri_predictions\A0A0N4XMR6_BP_predictions.csv
# deepfri_predictions\A0A0N9N9K4_BP_predictions.csv
# deepfri_predictions\A0A0P1IN84_CC_predictions.csv
# deepfri_predictions\A0A0R2P6D3_CC_predictions.csv
# deepfri_predictions\A0A0S7X2L7_BP_predictions.csv
# ...
